# %% [markdown]
# # 2021-0802 Zach Gardner
#
# Prepared by Nick Machairas
#
# Updated on Aug 18 2021
#
# Assumptions:
# - Layers are always encountered in the order presented (columns left to right)

# %%
import os
import numpy as np
import pandas as pd

# %%
df = pd.read_excel(
    os.path.join('files', '2021-0813-HAI-BWH-SummaryTable.xlsx'),
    usecols='B,D,E,I,K,N,Q,T,W,Z,AC',
    skiprows=[0,1,2,3,5,6,7],
    na_values=['NE', 'ne'],
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362 entries, 0 to 361
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   SOURCE FILE NAME               352 non-null    object
#  1   TEST BORING                    352 non-null    object
#  2   DEPTH OF                       352 non-null    object
#  3   FILL                           339 non-null    float64
#  4   ORGANIC DEPOSITS               42 non-null     float64
#  5   MARINE SAND DEPOSITS           118 non-null    float64
#  6    MARINE CLAY DEPOSITS          312 non-null    float64
#  7   GLACIOFLUVIAL (SAND) DEPOSITS  157 non-null    float64
#  8   GLACIAL TILL                   181 non-null    float64
#  9   WEATHERED BEDROCK              20 non-null     float64
#  10  BEDROCK                        86 non-null     float64
# dtypes: float64(8), object(3)
# memory usage: 31.2+ KB

# %%
df
# Out:
#                        SOURCE FILE NAME TEST BORING DEPTH OF  FILL  \
# 0    2013-0228-HAI-BBF-GeotechRpt-F.pdf      HA12-1      106   0.0
# 1    2013-0228-HAI-BBF-GeotechRpt-F.pdf     HA12-1A       94   0.0
# 2    2013-0228-HAI-BBF-GeotechRpt-F.pdf      HA12-3       94   0.0
# 3    2013-0228-HAI-BBF-GeotechRpt-F.pdf      HA12-4    100.5   0.0
# 4    2013-0228-HAI-BBF-GeotechRpt-F.pdf      HA12-5     92.5   0.0
# ..                                  ...         ...      ...   ...
# 357                                 NaN         NaN      NaN   NaN
# 358                                 NaN         NaN      NaN   NaN
# 359                                 NaN         NaN      NaN   NaN
# 360                                 NaN         NaN      NaN   NaN
# 361                                 NaN         NaN      NaN   NaN
#
#      ORGANIC DEPOSITS  MARINE SAND DEPOSITS   MARINE CLAY DEPOSITS  \
# 0                 NaN                   NaN                    9.0
# 1                 NaN                   NaN                   12.0
# 2                 NaN                   NaN                   14.0
# 3                 NaN                   NaN                    7.5
# 4                 9.0                   NaN                   14.0
# ..                ...                   ...                    ...
# 357               NaN                   NaN                    NaN
# 358               NaN                   NaN                    NaN
# 359               NaN                   NaN                    NaN
# 360               NaN                   NaN                    NaN
# 361               NaN                   NaN                    NaN
#
#      GLACIOFLUVIAL (SAND) DEPOSITS  GLACIAL TILL  WEATHERED BEDROCK  BEDROCK
# 0                             26.0          60.0                NaN     90.5
# 1                             24.0          64.0                NaN     90.7
# 2                             26.0          50.0                NaN     87.0
# 3                             29.0          50.0                NaN     83.0
# 4                             38.0          65.5                NaN     89.0
# ..                             ...           ...                ...      ...
# 357                            NaN           NaN                NaN      NaN
# 358                            NaN           NaN                NaN      NaN
# 359                            NaN           NaN                NaN      NaN
# 360                            NaN           NaN                NaN      NaN
# 361                            NaN           NaN                NaN      NaN
#
# [362 rows x 11 columns]

# %% [markdown]
# Main script:

# %%
with open(os.path.join('files', '2021-0813 - Field Geological Descriptions.csv'), 'w') as f:
    f.write('Location ID,Depth Top,Depth Base,Geology Code,Location Code\n')
    for i in df.index:
        bor = df.iloc[i]
        if pd.notna(bor['TEST BORING']):
            bor = bor.dropna()
            layers = list(bor[3:].items())
            if layers:
                for k, l in zip(layers[:-1], layers[1:]):
                    f.write(f"{bor['TEST BORING']},{k[1]},{l[1]},{k[0]},{bor['SOURCE FILE NAME']}\n")
                f.write(f"{bor['TEST BORING']},{layers[-1][1]},{bor['DEPTH OF']},{layers[-1][0]},{bor['SOURCE FILE NAME']}\n")
